# %%
import numpy as np
import pandas as pd
import sys
sys.path.append('/home/danilach/mipt-stats/SberTs')

# %load_ext autoreload
# %autoreload 2

from utils.models import DummyConditionalModel, VARModel
from utils.vis import plot_error_matrix, plot_model_pred, calc_average_error
from utils.interface import cross_validate_model, calc_avg_error, build_error_matrix, build_short_error_matrix
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## АПК

# %% [markdown]
# ### 24

# %%
df = pd.read_csv("/home/danilach/mipt-stats/SberTs/results/code/sarima_apk_24.csv", index_col=0)
plot_error_matrix(df)
print(f"MAPE: {np.mean(df):.2f}%")
# Out:
# MAPE: 24.46%

# %% [markdown]
# ### 36

# %%
df = pd.read_csv("/home/danilach/mipt-stats/SberTs/results/code/sarima_apk_36.csv", index_col=0)
plot_error_matrix(df)
print(f"MAPE: {np.mean(df):.2f}%")
# Out:
# MAPE: 28.96%

# %% [markdown]
# ### 48

# %%
df = pd.read_csv("/home/danilach/mipt-stats/SberTs/results/code/sarima_apk_48.csv", index_col=0)
plot_error_matrix(df)
print(f"MAPE: {np.mean(df):.2f}%")
# Out:
# MAPE: 23.07%

# %% [markdown]
# ## Chemicals

# %% [markdown]
# ### 24

# %%
df = pd.read_csv("/home/danilach/mipt-stats/SberTs/results/code/sarima_chemicals_24.csv", index_col=0)
plot_error_matrix(df)
print(f"MAPE: {np.mean(df):.2f}%")
# Out:
# MAPE: 74.99%

# %% [markdown]
# ### 36

# %%
df = pd.read_csv("/home/danilach/mipt-stats/SberTs/results/code/sarima_chemicals_36.csv", index_col=0)
plot_error_matrix(df)
print(f"MAPE: {np.mean(df):.2f}%")
# Out:
# MAPE: 116.54%

# %% [markdown]
# ### 48

# %%
df = pd.read_csv("/home/danilach/mipt-stats/SberTs/results/code/sarima_chemicals_48.csv", index_col=0)
plot_error_matrix(df)
print(f"MAPE: {np.mean(df):.2f}%")
# Out:
# MAPE: 34.25%
